# %% [markdown]
# **Handwritten Image Analysis**

# %%
import cv2, os
data_dir = 'data'
os.listdir(data_dir)
# Out:
# ['Invalid', 'valid', 'zoomed']

# %%
import imghdr
image_ext = ['jpeg','jpg','png','bmp']
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir,image_class)):
        try:    
            image_path = os.listdir(os.path.join(data_dir,image_class,image))
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_ext:
                os.remove(image_path)
        except Exception as e:
            print("no remove")
# Out:
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# no remove
# C:\Users\aswin\AppData\Local\Temp\ipykernel_17484\1259500580.py:1: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %% [markdown]
# **Pdf Extraction**

# %%
import fitz  # PyMuPDF
import os

def extract_images_from_pdf(pdf_path, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    for page_number in range(pdf_document.page_count):
        page = pdf_document.load_page(page_number)

        # Get the images on the page
        images = page.get_images(full=True)

        for img_index, img_info in enumerate(images):
            image_index = img_info[0]

            # Get the image
            image = pdf_document.extract_image(image_index)
            image_bytes = image["image"]

            # Save the image to a file
            image_filename = f"page{page_number + 1}_img{img_index + 1}.png"
            image_path = os.path.join(output_folder, image_filename)

            with open(image_path, "wb") as image_file:
                image_file.write(image_bytes)

    # Close the PDF document
    pdf_document.close()

if __name__ == "__main__":
    pdf_file_path = "C:/Users/aswin/Downloads/Khan Sir Hindi Complete Notes.pdf"
    output_folder_path = "data"

    extract_images_from_pdf(pdf_file_path, output_folder_path)

# %% [markdown]
# **Number Marking**

# %%
import os

def rename_images_in_folder(folder_path):
    files = os.listdir(folder_path)

    image_files = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))]
    image_files.sort()

    for index, old_name in enumerate(image_files, start=1):
        file_extension = os.path.splitext(old_name)[1]
        new_name = f"{index}{file_extension}"

        old_path = os.path.join(folder_path, old_name)
        new_path = os.path.join(folder_path, new_name)

        os.rename(old_path, new_path)
        print(f'Renamed: {old_path} -> {new_path}')

if __name__ == "__main__":
    folder_path = "data/Invalid"

    rename_images_in_folder(folder_path)
# Out:
# Renamed: data/Invalid\adofldlc.jpg -> data/Invalid\1.jpg
# Renamed: data/Invalid\aeoglkrw.png -> data/Invalid\2.png
# Renamed: data/Invalid\aipkolvn.png -> data/Invalid\3.png
# Renamed: data/Invalid\algahxrt.png -> data/Invalid\4.png
# Renamed: data/Invalid\apzrkdsq.png -> data/Invalid\5.png
# Renamed: data/Invalid\aqmqiicp.jpg -> data/Invalid\6.jpg
# Renamed: data/Invalid\aswbqdho.jpg -> data/Invalid\7.jpg
# Renamed: data/Invalid\awbcavuw.png -> data/Invalid\8.png
# Renamed: data/Invalid\bcoftmkc.jpg -> data/Invalid\9.jpg
# Renamed: data/Invalid\bgvtikcn.jpg -> data/Invalid\10.jpg
# Renamed: data/Invalid\bhtufahu.jpg -> data/Invalid\11.jpg
# Renamed: data/Invalid\bhxsldpd.jpg -> data/Invalid\12.jpg
# Renamed: data/Invalid\blmshwsd.jpg -> data/Invalid\13.jpg
# Renamed: data/Invalid\bnyxxrip.jpg -> data/Invalid\14.jpg
# Renamed: data/Invalid\bqmtimuq.jpg -> data/Invalid\15.jpg
# Renamed: data/Invalid\bsaccwdm.jpg -> data/Invalid\16.jpg
# Renamed: data/Invalid\bwrkzfyb.png -> data/Invalid\17.png
# Renamed: data/Invalid\bwsoodfn.png -> data/Invalid\18.png
# Renamed: data/Invalid\byhysbpb.jpg -> data/Invalid\19.jpg
# Renamed: data/Invalid\cfrlptbn.jpg -> data/Invalid\20.jpg
# Renamed: data/Invalid\cgfrxyhx.png -> data/Invalid\21.png
# Renamed: data/Invalid\cjboirht.jpeg -> data/Invalid\22.jpeg
# Renamed: data/Invalid\cjzikkjg.jpg -> data/Invalid\23.jpg
# Renamed: data/Invalid\cklztqnq.jpg -> data/Invalid\24.jpg
# Renamed: data/Invalid\cwgfffzd.png -> data/Invalid\25.png
# Renamed: data/Invalid\cwklfxkf.png -> data/Invalid\26.png
# Renamed: data/Invalid\cyedxzaq.jpg -> data/Invalid\27.jpg
# Renamed: data/Invalid\cyqgscbe.jpg -> data/Invalid\28.jpg
# Renamed: data/Invalid\cywdzdvx.jpg -> data/Invalid\29.jpg
# Renamed: data/Invalid\czwaslht.jpg -> data/Invalid\30.jpg
# Renamed: data/Invalid\dcfrkmdc.jpg -> data/Invalid\31.jpg
# Renamed: data/Invalid\dcgyjlkg.jpg -> data/Invalid\32.jpg
# Renamed: data/Invalid\dhyvzisq.png -> data/Invalid\33.png
# Renamed: data/Invalid\dlmcvvuz.png -> data/Invalid\34.png
# Renamed: data/Invalid\dsuedjca.jpg -> data/Invalid\35.jpg
# Renamed: data/Invalid\dtirzgae.jpg -> data/Invalid\36.jpg
# Renamed: data/Invalid\dxvalpss.jpg -> data/Invalid\37.jpg
# Renamed: data/Invalid\eaceslbb.png -> data/Invalid\38.png
# Renamed: data/Invalid\ebomciiv.jpg -> data/Invalid\39.jpg
# Renamed: data/Invalid\ehbyxsvi.jpg -> data/Invalid\40.jpg
# Renamed: data/Invalid\eoefokmw.jpg -> data/Invalid\41.jpg
# Renamed: data/Invalid\epqooaxz.jpg -> data/Invalid\42.jpg
# Renamed: data/Invalid\eqozulus.png -> data/Invalid\43.png
# Renamed: data/Invalid\ffghjwop.jpg -> data/Invalid\44.jpg
# Renamed: data/Invalid\fjrrpaxr.png -> data/Invalid\45.png
# Renamed: data/Invalid\fogfrcct.png -> data/Invalid\46.png
# Renamed: data/Invalid\frzucvdy.jpg -> data/Invalid\47.jpg
# Renamed: data/Invalid\fuedmrcg.png -> data/Invalid\48.png
# Renamed: data/Invalid\fywhgluj.png -> data/Invalid\49.png
# Renamed: data/Invalid\gghdbjhz.jpg -> data/Invalid\50.jpg
# Renamed: data/Invalid\gntfabpw.jpg -> data/Invalid\51.jpg
# Renamed: data/Invalid\goyhiqdo.png -> data/Invalid\52.png
# Renamed: data/Invalid\gqaczjdc.png -> data/Invalid\53.png
# Renamed: data/Invalid\hckwsvap.png -> data/Invalid\54.png
# Renamed: data/Invalid\hnzucbaa.png -> data/Invalid\55.png
# Renamed: data/Invalid\hojefuoo.jpg -> data/Invalid\56.jpg
# Renamed: data/Invalid\hrqxqxft.png -> data/Invalid\57.png
# Renamed: data/Invalid\htgpliwo.jpg -> data/Invalid\58.jpg
# Renamed: data/Invalid\hxdrqhyb.jpg -> data/Invalid\59.jpg
# Renamed: data/Invalid\iakapyvi.png -> data/Invalid\60.png
# Renamed: data/Invalid\iknurpoa.jpg -> data/Invalid\61.jpg
# Renamed: data/Invalid\issfnaqi.jpg -> data/Invalid\62.jpg
# Renamed: data/Invalid\itdytony.png -> data/Invalid\63.png
# Renamed: data/Invalid\iybxgcbk.jpg -> data/Invalid\64.jpg
# Renamed: data/Invalid\iyulieym.jpg -> data/Invalid\65.jpg
# Renamed: data/Invalid\jbroixhr.jpg -> data/Invalid\66.jpg
# Renamed: data/Invalid\jfcsfjqa.png -> data/Invalid\67.png
# Renamed: data/Invalid\jfvznics.jpg -> data/Invalid\68.jpg
# Renamed: data/Invalid\jkdocniz.jpg -> data/Invalid\69.jpg
# Renamed: data/Invalid\jludxwni.jpg -> data/Invalid\70.jpg
# Renamed: data/Invalid\jmqmadyp.jpg -> data/Invalid\71.jpg
# Renamed: data/Invalid\jqlvfgxu.jpg -> data/Invalid\72.jpg
# Renamed: data/Invalid\jrfyumel.jpg -> data/Invalid\73.jpg
# Renamed: data/Invalid\juvminno.jpg -> data/Invalid\74.jpg
# Renamed: data/Invalid\jvnhejzg.png -> data/Invalid\75.png
# Renamed: data/Invalid\kastywvk.jpg -> data/Invalid\76.jpg
# Renamed: data/Invalid\kewhcgog.png -> data/Invalid\77.png
# Renamed: data/Invalid\kkdayjeu.jpg -> data/Invalid\78.jpg
# Renamed: data/Invalid\kkequkes.jpg -> data/Invalid\79.jpg
# Renamed: data/Invalid\kleglygz.jpg -> data/Invalid\80.jpg
# Renamed: data/Invalid\klofqhkw.jpg -> data/Invalid\81.jpg
# Renamed: data/Invalid\knajwych.jpg -> data/Invalid\82.jpg
# Renamed: data/Invalid\knalvoyo.jpeg -> data/Invalid\83.jpeg
# Renamed: data/Invalid\koepcmtb.png -> data/Invalid\84.png
# Renamed: data/Invalid\kvuanjpl.jpg -> data/Invalid\85.jpg
# Renamed: data/Invalid\kxgyqzqu.jpg -> data/Invalid\86.jpg
# Renamed: data/Invalid\lbfvrooz.png -> data/Invalid\87.png
# Renamed: data/Invalid\lgmwicqe.jpg -> data/Invalid\88.jpg
# Renamed: data/Invalid\lilsvbpm.jpg -> data/Invalid\89.jpg
# Renamed: data/Invalid\lkbgnvxn.jpg -> data/Invalid\90.jpg
# Renamed: data/Invalid\lmgrvibb.png -> data/Invalid\91.png
# Renamed: data/Invalid\lnyddqvf.jpg -> data/Invalid\92.jpg
# Renamed: data/Invalid\lorbfahz.jpg -> data/Invalid\93.jpg
# Renamed: data/Invalid\lqiupcod.png -> data/Invalid\94.png
# Renamed: data/Invalid\lsjfqeet.jpg -> data/Invalid\95.jpg
# Renamed: data/Invalid\mbvyizdc.png -> data/Invalid\96.png
# Renamed: data/Invalid\mgxsncne.png -> data/Invalid\97.png
# Renamed: data/Invalid\mhotgnhb.png -> data/Invalid\98.png
# Renamed: data/Invalid\mjdfqheb.png -> data/Invalid\99.png
# Renamed: data/Invalid\mqnskelx.jpg -> data/Invalid\100.jpg
# Renamed: data/Invalid\mquzjlbb.png -> data/Invalid\101.png
# Renamed: data/Invalid\msyzuwvy.jpg -> data/Invalid\102.jpg
# Renamed: data/Invalid\mumrtyri.png -> data/Invalid\103.png
# Renamed: data/Invalid\mupcsght.jpg -> data/Invalid\104.jpg
# Renamed: data/Invalid\mvjpfnmu.png -> data/Invalid\105.png
# Renamed: data/Invalid\nbvuqpag.jpg -> data/Invalid\106.jpg
# Renamed: data/Invalid\nftgecog.jpg -> data/Invalid\107.jpg
# Renamed: data/Invalid\nuvkjnvm.png -> data/Invalid\108.png
# Renamed: data/Invalid\oxwctlln.jpg -> data/Invalid\109.jpg
# Renamed: data/Invalid\oyilatvp.jpg -> data/Invalid\110.jpg
# Renamed: data/Invalid\oztggiti.png -> data/Invalid\111.png
# Renamed: data/Invalid\pamrqgzx.png -> data/Invalid\112.png
# Renamed: data/Invalid\pasrxwmx.jpg -> data/Invalid\113.jpg
# Renamed: data/Invalid\peafwchs.jpg -> data/Invalid\114.jpg
# Renamed: data/Invalid\ppfiruke.png -> data/Invalid\115.png
# Renamed: data/Invalid\qiitvdgn.jpg -> data/Invalid\116.jpg
# Renamed: data/Invalid\qiqctaqb.jpg -> data/Invalid\117.jpg
# Renamed: data/Invalid\qkehvgfd.jpg -> data/Invalid\118.jpg
# Renamed: data/Invalid\qkqavtzc.jpg -> data/Invalid\119.jpg
# Renamed: data/Invalid\qltsgzuv.png -> data/Invalid\120.png
# Renamed: data/Invalid\qnzjlbxd.jpg -> data/Invalid\121.jpg
# Renamed: data/Invalid\qqbkrjhk.jpg -> data/Invalid\122.jpg
# Renamed: data/Invalid\qqgwxidj.jpg -> data/Invalid\123.jpg
# Renamed: data/Invalid\qvxhhzpz.jpg -> data/Invalid\124.jpg
# Renamed: data/Invalid\qzhjysdk.jpg -> data/Invalid\125.jpg
# Renamed: data/Invalid\qztbbmoq.png -> data/Invalid\126.png
# Renamed: data/Invalid\rjusphie.png -> data/Invalid\127.png
# Renamed: data/Invalid\rjwduetp.jpg -> data/Invalid\128.jpg
# Renamed: data/Invalid\rrjjreue.png -> data/Invalid\129.png
# Renamed: data/Invalid\rvncnzbx.jpg -> data/Invalid\130.jpg
# Renamed: data/Invalid\rvzhshqz.png -> data/Invalid\131.png
# Renamed: data/Invalid\sdlubalk.jpg -> data/Invalid\132.jpg
# Renamed: data/Invalid\setffktg.jpg -> data/Invalid\133.jpg
# Renamed: data/Invalid\sflicrue.jpg -> data/Invalid\134.jpg
# Renamed: data/Invalid\smkkorra.jpg -> data/Invalid\135.jpg
# Renamed: data/Invalid\soxyzbhd.jpg -> data/Invalid\136.jpg
# Renamed: data/Invalid\sucjjpah.jpg -> data/Invalid\137.jpg
# Renamed: data/Invalid\tayowvdh.jpg -> data/Invalid\138.jpg
# Renamed: data/Invalid\tweiuwxa.jpg -> data/Invalid\139.jpg
# Renamed: data/Invalid\tzuaejae.jpg -> data/Invalid\140.jpg
# Renamed: data/Invalid\ufddkdbd.png -> data/Invalid\141.png
# Renamed: data/Invalid\uidesqxa.jpg -> data/Invalid\142.jpg
# Renamed: data/Invalid\ultvslrk.jpg -> data/Invalid\143.jpg
# Renamed: data/Invalid\umqsbndk.jpg -> data/Invalid\144.jpg
# Renamed: data/Invalid\uvrszyyl.jpg -> data/Invalid\145.jpg
# Renamed: data/Invalid\uzluigcw.jpg -> data/Invalid\146.jpg
# Renamed: data/Invalid\vkgkzqfd.jpg -> data/Invalid\147.jpg
# Renamed: data/Invalid\vwupycfl.png -> data/Invalid\148.png
# Renamed: data/Invalid\whedyiwd.jpg -> data/Invalid\149.jpg
# Renamed: data/Invalid\wiwaimcj.jpg -> data/Invalid\150.jpg
# Renamed: data/Invalid\wkejdaiq.png -> data/Invalid\151.png
# Renamed: data/Invalid\wuhvhiao.jpg -> data/Invalid\152.jpg
# Renamed: data/Invalid\wygqlhea.jpg -> data/Invalid\153.jpg
# Renamed: data/Invalid\xcqecoak.png -> data/Invalid\154.png
# Renamed: data/Invalid\xixxmlkt.jpg -> data/Invalid\155.jpg
# Renamed: data/Invalid\xsillhef.png -> data/Invalid\156.png
# Renamed: data/Invalid\ypluaiok.jpg -> data/Invalid\157.jpg
# Renamed: data/Invalid\ytmsxzut.jpg -> data/Invalid\158.jpg
# Renamed: data/Invalid\ytrmyagc.jpg -> data/Invalid\159.jpg
# Renamed: data/Invalid\yzlutjlr.jpg -> data/Invalid\160.jpg
# Renamed: data/Invalid\zcmwrusf.jpg -> data/Invalid\161.jpg
# Renamed: data/Invalid\zwihnbyy.jpg -> data/Invalid\162.jpg

# %% [markdown]
# **Name Resetting**

# %%
import os
import uuid
import string
import random

def generate_random_word(length=8):
    return ''.join(random.choice(string.ascii_lowercase) for _ in range(length))

def rename_files_in_folder_to_random_words(folder_path):
    files = os.listdir(folder_path)
    random.shuffle(files)

    for file_name in files:
        random_word = generate_random_word()
        file_extension = os.path.splitext(file_name)[1]

        old_path = os.path.join(folder_path, file_name)
        new_path = os.path.join(folder_path, f"{random_word}{file_extension}")

        os.rename(old_path, new_path)
        print(f'Renamed: {old_path} -> {new_path}')

if __name__ == "__main__":
    folder_path = "data/Invalid"

    rename_files_in_folder_to_random_words(folder_path)
# Out:
# Renamed: data/Invalid\89.jpg -> data/Invalid\xixxmlkt.jpg
# Renamed: data/Invalid\42.png -> data/Invalid\mgxsncne.png
# Renamed: data/Invalid\augmented_WhatsApp Image 2024-01-12 at 21.45.58_6de03394.jpg -> data/Invalid\uidesqxa.jpg
# Renamed: data/Invalid\133.png -> data/Invalid\xcqecoak.png
# Renamed: data/Invalid\WhatsApp Image 2024-01-12 at 20.43.51_45d45283.jpg -> data/Invalid\bhxsldpd.jpg
# Renamed: data/Invalid\103.jpg -> data/Invalid\lgmwicqe.jpg
# Renamed: data/Invalid\91.jpg -> data/Invalid\msyzuwvy.jpg
# Renamed: data/Invalid\101.png -> data/Invalid\cwklfxkf.png
# Renamed: data/Invalid\augmented_invalid_test_2.jpg -> data/Invalid\wuhvhiao.jpg
# Renamed: data/Invalid\augmented_augmented_invalid_test_2.jpg -> data/Invalid\nbvuqpag.jpg
# Renamed: data/Invalid\118.jpg -> data/Invalid\lnyddqvf.jpg
# Renamed: data/Invalid\98.png -> data/Invalid\mhotgnhb.png
# Renamed: data/Invalid\151.png -> data/Invalid\xsillhef.png
# Renamed: data/Invalid\126.jpg -> data/Invalid\ytrmyagc.jpg
# Renamed: data/Invalid\8.png -> data/Invalid\eaceslbb.png
# Renamed: data/Invalid\136.png -> data/Invalid\hckwsvap.png
# Renamed: data/Invalid\132.jpg -> data/Invalid\dtirzgae.jpg
# Renamed: data/Invalid\52.jpg -> data/Invalid\tweiuwxa.jpg
# Renamed: data/Invalid\92.jpg -> data/Invalid\gntfabpw.jpg
# Renamed: data/Invalid\20.jpg -> data/Invalid\sflicrue.jpg
# Renamed: data/Invalid\30.jpg -> data/Invalid\kkdayjeu.jpg
# Renamed: data/Invalid\WhatsApp Image 2024-01-12 at 20.44.21_379da00c.jpg -> data/Invalid\qkqavtzc.jpg
# Renamed: data/Invalid\108.jpg -> data/Invalid\rvncnzbx.jpg
# Renamed: data/Invalid\23.jpg -> data/Invalid\pasrxwmx.jpg
# Renamed: data/Invalid\63.jpg -> data/Invalid\qzhjysdk.jpg
# Renamed: data/Invalid\28.png -> data/Invalid\mjdfqheb.png
# Renamed: data/Invalid\6.png -> data/Invalid\rjusphie.png
# Renamed: data/Invalid\146.jpg -> data/Invalid\dcfrkmdc.jpg
# Renamed: data/Invalid\109.jpg -> data/Invalid\bhtufahu.jpg
# Renamed: data/Invalid\43.png -> data/Invalid\lmgrvibb.png
# Renamed: data/Invalid\augmented_WhatsApp Image 2024-01-12 at 20.44.21_379da00c.jpg -> data/Invalid\uvrszyyl.jpg
# Renamed: data/Invalid\107.png -> data/Invalid\itdytony.png
# Renamed: data/Invalid\134.jpg -> data/Invalid\ytmsxzut.jpg
# Renamed: data/Invalid\augmented_augmented_WhatsApp Image 2024-01-12 at 20.44.08_c7d920a4.jpg -> data/Invalid\bnyxxrip.jpg
# Renamed: data/Invalid\11.png -> data/Invalid\awbcavuw.png
# Renamed: data/Invalid\49.jpg -> data/Invalid\lorbfahz.jpg
# Renamed: data/Invalid\44.png -> data/Invalid\eqozulus.png
# Renamed: data/Invalid\90.png -> data/Invalid\koepcmtb.png
# Renamed: data/Invalid\123.jpg -> data/Invalid\aqmqiicp.jpg
# Renamed: data/Invalid\110.png -> data/Invalid\goyhiqdo.png
# Renamed: data/Invalid\2.png -> data/Invalid\qztbbmoq.png
# Renamed: data/Invalid\125.jpg -> data/Invalid\soxyzbhd.jpg
# Renamed: data/Invalid\88.jpg -> data/Invalid\kleglygz.jpg
# Renamed: data/Invalid\124.png -> data/Invalid\cwgfffzd.png
# Renamed: data/Invalid\81.jpg -> data/Invalid\tzuaejae.jpg
# Renamed: data/Invalid\55.png -> data/Invalid\mbvyizdc.png
# Renamed: data/Invalid\142.jpg -> data/Invalid\gghdbjhz.jpg
# Renamed: data/Invalid\117.png -> data/Invalid\gqaczjdc.png
# Renamed: data/Invalid\120.png -> data/Invalid\apzrkdsq.png
# Renamed: data/Invalid\31.jpg -> data/Invalid\klofqhkw.jpg
# Renamed: data/Invalid\87.jpg -> data/Invalid\eoefokmw.jpg
# Renamed: data/Invalid\100.png -> data/Invalid\ufddkdbd.png
# Renamed: data/Invalid\5.jpg -> data/Invalid\setffktg.jpg
# Renamed: data/Invalid\68.png -> data/Invalid\rrjjreue.png
# Renamed: data/Invalid\70.png -> data/Invalid\cgfrxyhx.png
# Renamed: data/Invalid\67.jpg -> data/Invalid\frzucvdy.jpg
# Renamed: data/Invalid\augmented_WhatsApp Image 2024-01-12 at 20.43.39_c7fc3a4b.jpg -> data/Invalid\czwaslht.jpg
# Renamed: data/Invalid\137.jpg -> data/Invalid\knajwych.jpg
# Renamed: data/Invalid\119.jpg -> data/Invalid\nftgecog.jpg
# Renamed: data/Invalid\121.png -> data/Invalid\mvjpfnmu.png
# Renamed: data/Invalid\augmented_augmented_WhatsApp Image 2024-01-12 at 20.43.51_45d45283.jpg -> data/Invalid\lilsvbpm.jpg
# Renamed: data/Invalid\129.jpg -> data/Invalid\lkbgnvxn.jpg
# Renamed: data/Invalid\105.png -> data/Invalid\fuedmrcg.png
# Renamed: data/Invalid\augmented_augmented_WhatsApp Image 2024-01-12 at 20.43.39_c7fc3a4b.jpg -> data/Invalid\qvxhhzpz.jpg
# Renamed: data/Invalid\18.png -> data/Invalid\mumrtyri.png
# Renamed: data/Invalid\149.jpg -> data/Invalid\wiwaimcj.jpg
# Renamed: data/Invalid\86.jpg -> data/Invalid\juvminno.jpg
# Renamed: data/Invalid\113.png -> data/Invalid\qltsgzuv.png
# Renamed: data/Invalid\71.jpg -> data/Invalid\rjwduetp.jpg
# Renamed: data/Invalid\34.png -> data/Invalid\wkejdaiq.png
# Renamed: data/Invalid\40.jpg -> data/Invalid\kvuanjpl.jpg
# Renamed: data/Invalid\93.jpg -> data/Invalid\iybxgcbk.jpg
# Renamed: data/Invalid\80.jpg -> data/Invalid\cywdzdvx.jpg
# Renamed: data/Invalid\9.png -> data/Invalid\fywhgluj.png
# Renamed: data/Invalid\102.jpg -> data/Invalid\bcoftmkc.jpg
# Renamed: data/Invalid\144.jpg -> data/Invalid\cyedxzaq.jpg
# Renamed: data/Invalid\99.png -> data/Invalid\fogfrcct.png
# Renamed: data/Invalid\115.jpg -> data/Invalid\hojefuoo.jpg
# Renamed: data/Invalid\152.jpg -> data/Invalid\bqmtimuq.jpg
# Renamed: data/Invalid\128.jpg -> data/Invalid\qqbkrjhk.jpg
# Renamed: data/Invalid\27.jpg -> data/Invalid\iyulieym.jpg
# Renamed: data/Invalid\66.jpg -> data/Invalid\tayowvdh.jpg
# Renamed: data/Invalid\15.jpg -> data/Invalid\blmshwsd.jpg
# Renamed: data/Invalid\96.jpg -> data/Invalid\dxvalpss.jpg
# Renamed: data/Invalid\114.png -> data/Invalid\hrqxqxft.png
# Renamed: data/Invalid\122.png -> data/Invalid\fjrrpaxr.png
# Renamed: data/Invalid\augmented_augmented_WhatsApp Image 2024-01-12 at 20.43.39_bd51042a.jpg -> data/Invalid\qiitvdgn.jpg
# Renamed: data/Invalid\85.jpg -> data/Invalid\jkdocniz.jpg
# Renamed: data/Invalid\54.jpg -> data/Invalid\yzlutjlr.jpg
# Renamed: data/Invalid\155.png -> data/Invalid\algahxrt.png
# Renamed: data/Invalid\WhatsApp Image 2024-01-12 at 20.43.39_c7fc3a4b.jpg -> data/Invalid\ebomciiv.jpg
# Renamed: data/Invalid\75.jpg -> data/Invalid\lsjfqeet.jpg
# Renamed: data/Invalid\7.jpg -> data/Invalid\oyilatvp.jpg
# Renamed: data/Invalid\135.jpg -> data/Invalid\ypluaiok.jpg
# Renamed: data/Invalid\97.png -> data/Invalid\mquzjlbb.png
# Renamed: data/Invalid\131.png -> data/Invalid\bwsoodfn.png
# Renamed: data/Invalid\61.jpg -> data/Invalid\hxdrqhyb.jpg
# Renamed: data/Invalid\140.jpg -> data/Invalid\qqgwxidj.jpg
# Renamed: data/Invalid\84.jpg -> data/Invalid\mqnskelx.jpg
# Renamed: data/Invalid\64.jpg -> data/Invalid\epqooaxz.jpg
# Renamed: data/Invalid\111.png -> data/Invalid\aeoglkrw.png
# Renamed: data/Invalid\32.jpg -> data/Invalid\htgpliwo.jpg
# Renamed: data/Invalid\145.jpg -> data/Invalid\cfrlptbn.jpg
# Renamed: data/Invalid\47.png -> data/Invalid\jfcsfjqa.png
# Renamed: data/Invalid\13.png -> data/Invalid\kewhcgog.png
# Renamed: data/Invalid\augmented_WhatsApp Image 2024-01-12 at 20.44.08_c7d920a4.jpg -> data/Invalid\ffghjwop.jpg
# Renamed: data/Invalid\65.jpg -> data/Invalid\bsaccwdm.jpg
# Renamed: data/Invalid\WhatsApp Image 2024-01-12 at 20.44.08_c7d920a4.jpg -> data/Invalid\kxgyqzqu.jpg
# Renamed: data/Invalid\39.jpg -> data/Invalid\jbroixhr.jpg
# Renamed: data/Invalid\51.png -> data/Invalid\lqiupcod.png
# Renamed: data/Invalid\77.jpg -> data/Invalid\zwihnbyy.jpg
# Renamed: data/Invalid\130.png -> data/Invalid\ppfiruke.png
# Renamed: data/Invalid\138.jpg -> data/Invalid\zcmwrusf.jpg
# Renamed: data/Invalid\139.jpg -> data/Invalid\smkkorra.jpg
# Renamed: data/Invalid\45.png -> data/Invalid\dhyvzisq.png
# Renamed: data/Invalid\48.jpg -> data/Invalid\bgvtikcn.jpg
# Renamed: data/Invalid\82.jpg -> data/Invalid\dcgyjlkg.jpg
# Renamed: data/Invalid\53.jpg -> data/Invalid\wygqlhea.jpg
# Renamed: data/Invalid\3.jpg -> data/Invalid\vkgkzqfd.jpg
# Renamed: data/Invalid\38.png -> data/Invalid\pamrqgzx.png
# Renamed: data/Invalid\12.png -> data/Invalid\hnzucbaa.png
# Renamed: data/Invalid\62.jpg -> data/Invalid\qiqctaqb.jpg
# Renamed: data/Invalid\143.jpg -> data/Invalid\byhysbpb.jpg
# Renamed: data/Invalid\73.png -> data/Invalid\bwrkzfyb.png
# Renamed: data/Invalid\41.jpg -> data/Invalid\jfvznics.jpg
# Renamed: data/Invalid\26.jpg -> data/Invalid\kkequkes.jpg
# Renamed: data/Invalid\154.png -> data/Invalid\nuvkjnvm.png
# Renamed: data/Invalid\augmented_WhatsApp Image 2024-01-12 at 20.43.39_bd51042a.jpg -> data/Invalid\uzluigcw.jpg
# Renamed: data/Invalid\14.jpg -> data/Invalid\adofldlc.jpg
# Renamed: data/Invalid\78.jpg -> data/Invalid\ultvslrk.jpg
# Renamed: data/Invalid\74.png -> data/Invalid\dlmcvvuz.png
# Renamed: data/Invalid\83.jpg -> data/Invalid\ehbyxsvi.jpg
# Renamed: data/Invalid\59.jpg -> data/Invalid\sdlubalk.jpg
# Renamed: data/Invalid\147.png -> data/Invalid\iakapyvi.png
# Renamed: data/Invalid\37.jpg -> data/Invalid\iknurpoa.jpg
# Renamed: data/Invalid\19.png -> data/Invalid\oztggiti.png
# Renamed: data/Invalid\4.jpg -> data/Invalid\jqlvfgxu.jpg
# Renamed: data/Invalid\augmented_WhatsApp Image 2024-01-12 at 20.43.51_45d45283.jpg -> data/Invalid\issfnaqi.jpg
# Renamed: data/Invalid\24.jpg -> data/Invalid\cklztqnq.jpg
# Renamed: data/Invalid\106.jpg -> data/Invalid\jrfyumel.jpg
# Renamed: data/Invalid\36.png -> data/Invalid\aipkolvn.png
# Renamed: data/Invalid\60.png -> data/Invalid\lbfvrooz.png
# Renamed: data/Invalid\104.jpg -> data/Invalid\jludxwni.jpg
# Renamed: data/Invalid\augmented_augmented_WhatsApp Image 2024-01-12 at 20.44.21_379da00c.jpg -> data/Invalid\kastywvk.jpg
# Renamed: data/Invalid\augmented_augmented_WhatsApp Image 2024-01-12 at 21.45.58_6de03394.jpg -> data/Invalid\qnzjlbxd.jpg
# Renamed: data/Invalid\150.jpg -> data/Invalid\aswbqdho.jpg
# Renamed: data/Invalid\94.jpg -> data/Invalid\whedyiwd.jpg
# Renamed: data/Invalid\57.jpg -> data/Invalid\dsuedjca.jpg
# Renamed: data/Invalid\10.jpg -> data/Invalid\mupcsght.jpg
# Renamed: data/Invalid\95.jpg -> data/Invalid\sucjjpah.jpg
# Renamed: data/Invalid\141.jpg -> data/Invalid\oxwctlln.jpg
# Renamed: data/Invalid\WhatsApp Image 2024-01-12 at 21.45.58_6de03394.jpg -> data/Invalid\peafwchs.jpg
# Renamed: data/Invalid\WhatsApp Image 2024-01-12 at 20.43.39_bd51042a.jpg -> data/Invalid\jmqmadyp.jpg
# Renamed: data/Invalid\116.png -> data/Invalid\vwupycfl.png
# Renamed: data/Invalid\153.jpg -> data/Invalid\cyqgscbe.jpg
# Renamed: data/Invalid\25.jpg -> data/Invalid\umqsbndk.jpg
# Renamed: data/Invalid\72.jpeg -> data/Invalid\cjboirht.jpeg
# Renamed: data/Invalid\58.jpeg -> data/Invalid\knalvoyo.jpeg
# Renamed: data/Invalid\50.png -> data/Invalid\rvzhshqz.png
# Renamed: data/Invalid\33.png -> data/Invalid\jvnhejzg.png
# Renamed: data/Invalid\69.jpg -> data/Invalid\qkehvgfd.jpg
# Renamed: data/Invalid\1.jpg -> data/Invalid\cjzikkjg.jpg

# %% [markdown]
# **Zoom Creation**

# %%
import os
import numpy as np
from PIL import Image
import cv2
input_dir = 'data/valid/'
output_dir = 'data/zoomed2/'
left = 500 
top = 500
right = 900
bottom = 900
for file in os.listdir(input_dir):
    file_path = os.path.join(input_dir, file)
    image = Image.open(file_path)
    cropped_image = image.crop((left, top, right, bottom))
    cropped_image = np.array(cropped_image)
    output_file_path = os.path.join(output_dir, f'cropped_{file}')
    cv2.imwrite(output_file_path,cropped_image)

# %% [markdown]
# **IAM Dataset cropping**

# %%
import cv2
import os
input_dir = 'C:/Users/aswin/OneDrive/Desktop/Work/IBM/data'
output_folder_path = 'cropped'
for folder_name in os.listdir(input_dir):
        folder_path = os.path.join(input_dir, folder_name)
        for filename in os.listdir(folder_path):
                file_path = os.path.join(folder_path, filename)
                img = cv2.imread(file_path)
                img_cropped = img[711:2780, 100:3000]
                output_file_path = os.path.join(output_folder_path, f'cropped_{filename}')
                cv2.imwrite(output_file_path, img_cropped)

# %% [markdown]
# **Augmentation**

# %%
import os
import albumentations as A
from PIL import Image
import numpy as np

def augment_and_save(image_path, save_path_prefix, num_augmentations=2):
    image = Image.open(image_path)
    image = np.array(image)
    
    augmentations = A.Compose([
        A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=10, p=1),
        A.RandomBrightnessContrast(p=1),
        A.HorizontalFlip(p=0.5)
    ])

    for i in range(num_augmentations):
        augmented_image = augmentations(image=image.copy())["image"]
        augmented_image = Image.fromarray(augmented_image)
        save_path = f"{save_path_prefix}_augmented_{i+1}.jpg"
        augmented_image.save(save_path)


image_directory = "file"
for filename in os.listdir(image_directory):
    image_path = os.path.join(image_directory, filename)
    save_path_prefix = os.path.join(image_directory, f"augmented_{filename[:-4]}")  # Remove file extension
    augment_and_save(image_path, save_path_prefix)

# %% [markdown]
# **Data Loading**

# %%
import tensorflow as tf
data = tf.keras.utils.image_dataset_from_directory(
    directory="data",
    image_size=(500, 500),
    shuffle=True,
    seed=42
)
# Out:
# Found 505 files belonging to 3 classes.

# %%
data.class_names
# Out:
# ['Invalid', 'valid', 'zoomed']

# %%
iter = data.as_numpy_iterator()
batch = iter.next()
batch[0].shape
# Out:
# (32, 500, 500, 3)

# %% [markdown]
# **Visualization**

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# **Preprocessing**

# %%
data = data.map(lambda x,y:(x/255.0,tf.one_hot(y,depth = 3)))

# %%
for x,y in data:
    print(y[0])
# Out:
# tf.Tensor([0. 0. 1.], shape=(3,), dtype=float32)
# tf.Tensor([1. 0. 0.], shape=(3,), dtype=float32)
# tf.Tensor([1. 0. 0.], shape=(3,), dtype=float32)
# tf.Tensor([0. 0. 1.], shape=(3,), dtype=float32)
# tf.Tensor([0. 1. 0.], shape=(3,), dtype=float32)
# tf.Tensor([1. 0. 0.], shape=(3,), dtype=float32)
# tf.Tensor([1. 0. 0.], shape=(3,), dtype=float32)
# tf.Tensor([1. 0. 0.], shape=(3,), dtype=float32)
# tf.Tensor([0. 1. 0.], shape=(3,), dtype=float32)
# tf.Tensor([0. 0. 1.], shape=(3,), dtype=float32)
# tf.Tensor([0. 0. 1.], shape=(3,), dtype=float32)
# tf.Tensor([0. 0. 1.], shape=(3,), dtype=float32)
# tf.Tensor([1. 0. 0.], shape=(3,), dtype=float32)
# tf.Tensor([1. 0. 0.], shape=(3,), dtype=float32)
# tf.Tensor([0. 0. 1.], shape=(3,), dtype=float32)
# tf.Tensor([0. 0. 1.], shape=(3,), dtype=float32)

# %%
batch = data.as_numpy_iterator().next()
print(batch[0].min(),batch[0].max())
# Out:
# 0.0 1.0

# %%
train_size = int(len(data)*.6)
val_size = int(len(data)*.3)
test_size = int(len(data)*.3)

# %%
len(data)
# Out:
# 16

# %%
print(train_size,val_size,test_size)
# Out:
# 9 4 4

# %% [markdown]
# **Train Test Validation Split**

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.applications import DenseNet169

base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(500, 500, 3))

base_model.trainable = False
model = Sequential()
model.add(base_model)
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 15, 15, 1664)      12642880
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 256)       3834112
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         295040
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 16936643 (64.61 MB)
# Trainable params: 4293763 (16.38 MB)
# Non-trainable params: 12642880 (48.23 MB)
# _________________________________________________________________

# %% [markdown]
# **Training**

# %%
model.fit(train,validation_data= val , epochs = 4)
# Out:
# Epoch 1/4
# 9/9 [==============================] - 127s 13s/step - loss: 1.5091 - accuracy: 0.5556 - val_loss: 0.3678 - val_accuracy: 0.8906
# Epoch 2/4
# 9/9 [==============================] - 115s 13s/step - loss: 0.4110 - accuracy: 0.8646 - val_loss: 0.2613 - val_accuracy: 0.9141
# Epoch 3/4
# 9/9 [==============================] - 116s 13s/step - loss: 0.2602 - accuracy: 0.9062 - val_loss: 0.1969 - val_accuracy: 0.9141
# Epoch 4/4
# 9/9 [==============================] - 116s 13s/step - loss: 0.1056 - accuracy: 0.9479 - val_loss: 0.0868 - val_accuracy: 0.9688

# %%
model.evaluate(test)
# Out:
# 3/3 [==============================] - 29s 7s/step - loss: 0.0772 - accuracy: 0.9663
# [0.0771561861038208, 0.966292142868042]

# %% [markdown]
# **Val model performance**

# %%
model.fit(train, epochs = 4,validation_data= val)
# Out:
# Epoch 1/4
# 5/5 [==============================] - 75s 13s/step - loss: 1.7086 - accuracy: 0.4812 - val_loss: 0.5254 - val_accuracy: 0.8125
# Epoch 2/4
# 5/5 [==============================] - 60s 12s/step - loss: 0.4739 - accuracy: 0.7625 - val_loss: 0.1957 - val_accuracy: 0.9375
# Epoch 3/4
# 5/5 [==============================] - 60s 12s/step - loss: 0.2439 - accuracy: 0.9062 - val_loss: 0.2238 - val_accuracy: 0.9688
# Epoch 4/4
# 5/5 [==============================] - 60s 12s/step - loss: 0.1033 - accuracy: 0.9688 - val_loss: 0.0532 - val_accuracy: 0.9688

# %%
model.evaluate(test)
# Out:
# 2/2 [==============================] - 15s 2s/step - loss: 0.0812 - accuracy: 0.9744
# [0.0811706930398941, 0.9743589758872986]

# %%
model.save('model_96.6.h5')
# Out:
# c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
with open("my_model.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\aswin\AppData\Local\Temp\tmpva7x1228\assets
# INFO:tensorflow:Assets written to: C:\Users\aswin\AppData\Local\Temp\tmpva7x1228\assets

# %% [markdown]
# **Testing**

# %%
import matplotlib.pyplot as plt
test = cv2.imread('valid_test_3.jpg')
plt.imshow(test)

# %%
from keras.models import load_model
model = load_model('models/model_96.6.h5')

# %%
import tensorflow as tf
import numpy as np
import cv2
image = cv2.imread("valid_test_3.jpg")
resize = tf.image.resize(image, (500,500))
np.expand_dims(resize, 0).shape
value = model.predict(np.expand_dims(resize/255 , 0))
# Out:
# 1/1 [==============================] - 1s 568ms/step

# %%
value
# Out:
# array([[0.05348112, 0.943619  , 0.00289978]], dtype=float32)

# %%
prediction = np.argmax(value)

# %%
if prediction ==1:
    print('This is a valid image')
elif prediction == 0:
    print('Image is either of bad quality or not in english')
else:
    print('Image is too zoomed please retake the image')
# Out:
# This is a valid image

# %% [markdown]
# DATA FROM EXCEL

# %%
import pandas as pd
df = pd.read_csv('data1.csv')

# %%
for i in range(103):
    df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\3548324195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handwriting Sample'][i] = df['Handwriting Sample'][i][df['Handwriting Sample'][i].find('(')+1:df['Handwriting Sample'][i].find(')')]

# %%
df.head(5)
# Out:
#       Survey Response        Date                     Email ID   Gender  Age  \
# 0  12/18/2023 11:28am  12-18-2023        achal.ajith@gmail.com  Female    22
# 1   12/18/2023 2:45pm  12-18-2023    arsalanahmad254@gmail.com     Male   26
# 2   12/18/2023 2:09pm  12-18-2023          r.nikhila@dummy.com  Female    20
# 3   12/18/2023 2:10pm  12-18-2023       kotha.ashwin@dummy.com     Male   19
# 4   12/18/2023 2:12pm  12-18-2023  rakshita.adhyapak@dummy.com  Female    20
#
#                                   Handwriting Sample
# 0  https://v5.airtableusercontent.com/v2/24/24/17...
# 1  https://v5.airtableusercontent.com/v2/24/24/17...
# 2  https://v5.airtableusercontent.com/v2/24/24/17...
# 3  https://v5.airtableusercontent.com/v2/24/24/17...
# 4  https://v5.airtableusercontent.com/v2/24/24/17...

# %%
df['Handwriting Sample'][99]
# Out:
# 'https://v5.airtableusercontent.com/v2/24/24/1703232000000/ZkfcZqJp9dzkqxtVTBkkTw/N1m_ij31LnFJGPopFGWFvtgjmIIeWA2naHD6ACqa5Y-aphI77HWFdyflWZDZk8px2OUdmBupClSxWk6ypVcKfAR3i4gmXqck3K2o0w1ZEkPrqQz2BVW3MIexh_WLVUwnf7pEVdhl93eYViIcO1ZE8Q/Vt9eGdYoRDEznY8E7BwCXaH0IRp5D5YducbhEpuulVQ'

# %%
df.to_csv('Data_formatted1.csv',index = False)

# %%
import pandas as pd
import urllib.request
import os

column_index = 5 
output_folder = 'download_1'
for index, row in df.iterrows():
    image_link = row[column_index]
    filename = image_link.split('/')[-1]
    output_path = os.path.join(output_folder, filename + '.png')

    try:
        urllib.request.urlretrieve(image_link, output_path)
        print(f"Image '{filename + '.png'}' downloaded successfully!")
    except Exception as e:
        print(f"Error downloading image '{filename + '.png'}': {e}")
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_220\4263653191.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   image_link = row[column_index]
# Image 'NyJUG3Ow5C8D4EPBs1BuzZx1c-PzWel8wxo6-2o0Ems.png' downloaded successfully!
# Image 'M5hEcD80Lhm4g-2HBZt8CzoLlPUYtaiPGzxVpbNeA4M.png' downloaded successfully!
# Image 'FbhKPR6EdddprS5aN1reew84ihiPEd-0Q7uh-JU7WYg.png' downloaded successfully!
# Image 'x03iPeev3vqb5g_rhgXK3OShm_doeHut3xrFSqGZq_8.png' downloaded successfully!
# Image 'MA2xXbd6LQWvH28Rnne6s2vFakrdOKCOttv9H-xgqoA.png' downloaded successfully!
# Image 'CrLprl4t8fV322bNUz3yOU0N1YSK4FExNuUldyS2JVI.png' downloaded successfully!
# Image 'VIpRspoJKkhkvQtFIdEuvqP4EmWMAiP3foMlrHDP3cI.png' downloaded successfully!
# Image 'FjvpGMYYzIwYQ3_kQtgy6hpAZqoS0v3-20GUnR65SM8.png' downloaded successfully!
# Image 'cZnQsby5JWJA1pCYW8pdX9FNqT2ttiARwRgjD9Qyjok.png' downloaded successfully!
# Image 'dsys05QPapZmHyVU5Hb9ArGQuqMsaEMFOiwJV_VbPKI.png' downloaded successfully!
# Image 'JFN_j05Ik79IFQNmBB8h_g7h3vU_yxzvfQ2_Zq8IQGg.png' downloaded successfully!
# Image 'C8pyWD25YSvYqIDHDW5RPeLm_vcrUnV8CnqpcID3jQg.png' downloaded successfully!
# Image 'ZJcLjhLO1Z-6uUimZbhJF82ocAPKDa8UHlTj-g1GlbE.png' downloaded successfully!
# Image 'hXXklXgyShTnKsIyWHx1pg-ffxINHJLgeFiD3iphJF4.png' downloaded successfully!
# Image 'VPfbH9Euq2sH2ySkwIebOM_reldeVzXGfXoy3QmOyCU.png' downloaded successfully!
# Image 'ooIcbqgJEQCq1y4pQYuSBiDzr8ncdWH4S_ELWQZKHiE.png' downloaded successfully!
# Image '60bUhbx_7VSdet1QsOBeQsd_2SbdvfVA-SudX1sy3rM.png' downloaded successfully!
# Image 'JRLiUF2Eloktq1xXTjMx9wdjweMtetUUfjsKMRBsnFs.png' downloaded successfully!
# Image 'o0OBs59Dk8AxWRGMDqP32reXpAuu82xwbqW7_qzlIfo.png' downloaded successfully!
# Image 'shElIVanjvOVOK1EVvdJ9xOb4qOvlDQvSHF0_OLqf78.png' downloaded successfully!
# Image 'UXwG399BqXmt0hnuKlhFOfJBHDeS-tur0iud-u5heko.png' downloaded successfully!
# Image 'HDclR8k1YBTIVwfrcFsv0-rx7b54Ah3wFAULMSq6F4w.png' downloaded successfully!
# Image 'JGt8qz-n_VPkbKQgmfihRW97iLtK4Wjz5HMzj5SNxDU.png' downloaded successfully!
# Image 'eSFvo_SKmnxPaB-44vCFLDEopDLZiMKbJmo3h5QuILc.png' downloaded successfully!
# Image 'IAB2wfM6OcxA-6l1yvtovvYGUuv-oBya-o2r6KcGFLk.png' downloaded successfully!
# Image '7suaiVmEknguhPkGp59uSNZBZouDifHZAwU4rddUJYY.png' downloaded successfully!
# Image 'w2XEvvd4_7_vtRpnyicMocmU-S7LF1pLiwHHFKZZbnc.png' downloaded successfully!
# Image 'jVP6cXPZu9pXWZAye0A0YDswG2iXew4jCg1mD7eRoF4.png' downloaded successfully!
# Image 'GFfzp_WMk2DQAmk6Nx3VaoSaZjQlQxP52vAg5DrVTxM.png' downloaded successfully!
# Image 'OWiTV0Od-7W69a6g17bphvkXrKPrwwGPtohFTwkDrnc.png' downloaded successfully!
# Image 'gNtv9AUVU-dwA_FrH3T1N6FzFXQdW-KYU-WXwyFHz0Y.png' downloaded successfully!
# Image 'Z0iJ3d2SS4StfWFMQncDAsGv86X75E1E10TtlW535S8.png' downloaded successfully!
# Image 'mgMZX43_wVA9HOfOO47Taq5n8ykVMBA609N6mnXoH0I.png' downloaded successfully!
# Image 'Z4KcT5EZ-P2YHvL1zGv7VZ9bYGhJlCn3C4FITMICunk.png' downloaded successfully!
# Image 'EhO4HggbufLDAPGEHIIKVlsGIQGRxZc7asdJ478FhQw.png' downloaded successfully!
# Image 'EuYrMLGtA6MKTwNlOOEPPyvuuZtdVReq0e9m3kmxnI8.png' downloaded successfully!
# Image 'KVRwKCs7Ux7iC_-pyMJ1q9dVIYT87ES-2tWzUYMT9EI.png' downloaded successfully!
# Image '_0Uk44VgTSjlO0PnYWmlohPAgFGMuvCVljD5QtYKFp0.png' downloaded successfully!
# Image 'lOAkPZ4D5iGT6IJNSC9YT4YC7nEC0Zgm1yk9d6RKHtU.png' downloaded successfully!
# Image 'yDZaszKRwr9FoewZu0T7iywA9IDZYts6iKLn125sAWQ.png' downloaded successfully!
# Image 'lK77xWMMxHEjIN0IUHomjtzhDoyE10M3k5HE74cdMIY.png' downloaded successfully!
# Image 'wlY6_dxPZFxhB0GbJqjx5qYQbYpOL_dXMI7celxwpE4.png' downloaded successfully!
# Image 'umA3TATvNja6YbOljhmc1kNXV_2vc9TtMnR8x607ebU.png' downloaded successfully!
# Image 'C_-vpykzEPEEgSDaBZ4CU54PQXAYBHibVksFhEuIer0.png' downloaded successfully!
# Image 'rL06UQk_vnqRlD8fLcrYq0KaeoXJIcOenoPxO0d3oPU.png' downloaded successfully!
# Image 'zHJTF6-kHtmA7hti5XtFpOXCVlJHtxhm5IMzrxFY8O4.png' downloaded successfully!
# Image 'B-BkAoE_qTcvYH-znWMDr6mBOzgdsTa0qlO0pjypSug.png' downloaded successfully!
# Image 'kze51aOF36ENwEEKM88p8deZ2193iFRAFDXcQ3YSoMM.png' downloaded successfully!
# Image '0scHLBMVM8sWn0mpMmBSLjafe1R-jO7NZc1c9XQsx4g.png' downloaded successfully!
# Image 'Jy6bdkrSYbi_vFiLWm6n1EfvuAlxLz7wT7dpIrCT8f4.png' downloaded successfully!
# Image 'hsGySKrdN1nATe6PgKyrbLEQAC-ScvdT2YmRi6doAPg.png' downloaded successfully!
# Image 'd6uMN0FKndeyo3qEOa6SFUIKCGf_Ar_kxyuKKOR7czQ.png' downloaded successfully!
# Image 'lCKRF4G0nZLSmmJ594h5fVsZNcgIdMW-u2uRkjShyQk.png' downloaded successfully!
# Image 'KG33_CUEarShamA4fobPweW3uUpBAPI2CZvgrm_aNGg.png' downloaded successfully!
# Image 'rcXrCGXVm2ufuh3onJXHHh-QiLjgGVS35kaITEp6CLA.png' downloaded successfully!
# Image 'ntnqHdV7x6C2ZtrjC92nJNLcR-Ge5V-h0ofI0PGaU4M.png' downloaded successfully!
# Image 'ALY_RjMEhAB2edWkntMW3FtYQ3Opd8frfPKMd791V0o.png' downloaded successfully!
# Image 'rjxdKRc5m8jDbCcfcMvB25mHkeBdQE709KlQfuwy9Ak.png' downloaded successfully!
# Image 'yE45Wq1ZzLlLKE1stJolDHnaSPNZOD91C6kMNXYt2T0.png' downloaded successfully!
# Image '1oPrVYlaUeSzJno4AKv1aPvCq38wwxf3lT42XaGc-m4.png' downloaded successfully!
# Image 'pDP40Pl89_hGg0HiEZuhSShbkn1rkMF_PGx9IYMPi3U.png' downloaded successfully!
# Image 'cf16z_dToVAYmmcKUm83c0iNvs2camzH37T7XENATX4.png' downloaded successfully!
# Image 'TbPC30JYbzLAJTxvS0LDMxQKVgBn6zgO8iyjWG75UdQ.png' downloaded successfully!
# Image 'mqVSB6iy86_49WS1AcWeql39jVdLFzNodRngmMAHPL4.png' downloaded successfully!
# Image '4euc6pT6wzAyhJDe1jkujiukoah8uhXAq3AjMxTdCwQ.png' downloaded successfully!
# Image '01BpQ4dOyY0cLbZMNbPLj91l1Ioyn2YtXiT9_TI54Lk.png' downloaded successfully!
# Image 'tu6_L7FBoPobD1nWU1IDSG_Cq7M8_f289wPWg6VYOGo.png' downloaded successfully!
# Image 'YmTJXqjio8rM4ZjfL3G1ceJSHoP6IgWQ5hJr2xLhpOI.png' downloaded successfully!
# Image '5oxJQxFoN5DQOq7cfqzcKE-C46RDWtyChh4KF77oKdQ.png' downloaded successfully!
# Image 'IkloByEZZ_L1mogf-H52YIp0lEVTQmKII3p4DMVQDr4.png' downloaded successfully!
# Image 'nqE1h-t9uvWnhG2Eva8khfkTojK_b1aGxHH8EAYGU6E.png' downloaded successfully!
# Image 'msuoJ7rzxEMolEZJ1pE4wXHt_leFhgorKRlLrMHd3Mw.png' downloaded successfully!
# Image 'xDJ_ytaGETmj2mE8gu50VLKMJzejJAum2d-zTXRvO1Q.png' downloaded successfully!
# Image 'Ady0KST94n25HB03Ptc8K0OXxXGFhbUJAHmfnX-Jp9Q.png' downloaded successfully!
# Image '2CwCvbQk6j3X9YS0w8iybSthICzo5_fWy6n3OpKCLTw.png' downloaded successfully!
# Image 'kt_J1wVdiFg2fWImMdBQCe56flS2wfOZQxA1YPvWdYg.png' downloaded successfully!
# Image 'BntElh-S-hO1oF7ApJNuygUwjyLNCRsvElIQ4XmXZqM.png' downloaded successfully!
# Image 'MjnSnYiOKosG0HW_HaVx5f9pgW1q1jF34k6iDvk2q0o.png' downloaded successfully!
# Image 'ZYXNQ0FFW4UoGsc0tcEmik_QDbI-h2nAJVkcNTCveIk.png' downloaded successfully!
# Image 'p2SVEurP5_0JJ1uz5s3pfrIcW5f-0RAJrP_loVk5lso.png' downloaded successfully!
# Image 'u8NZtlHnoEPX7AkeoHzJp3LYNtwP1THzZlYbPDmtpxQ.png' downloaded successfully!
# Image 'u3I4O5kKuiOy90Eh8Cyaa9Jm3JNzLc4IRieP9zv7hh4.png' downloaded successfully!
# Image 'xpjk6ZxOsgktPOAOHnorEf41XyoqTysxk5EAK55oimA.png' downloaded successfully!
# Image 'oe3jV5O3q1lQfpjnv9b5_xQStHr2eB4Y9yDiydi21ek.png' downloaded successfully!
# Image 'o1ZqRKjnHP-X_6guZCMFNcRBCYWJn4ZCF4VCKPK5u_M.png' downloaded successfully!
# Image '8BxSWmtNaXTx6tY-Dj2wGqkBczcw-89adWXgt4oPp1M.png' downloaded successfully!
# Image 'AJTxFyV3YyW9lurDsvBs-os9rlBSJilyfKR6je61p8A.png' downloaded successfully!
# Image 'hohjxOddvgJ1I9dl-J-UF3Ws6ylc79aHt4EXNlhNUaA.png' downloaded successfully!
# Image 'M3d7pEQ5i9bRSxipzNiHailW-Qz0O_0RkGRuEXvL3Dc.png' downloaded successfully!
# Image 'wVGq_u6qYQYM7SeS9W4I2CbGiaLKyGixbxMZQizb358.png' downloaded successfully!
# Image '61pS21cO9RxOEFkyHffw6qGzy0zl-fEVSihL41aBTbE.png' downloaded successfully!
# Image 'aBixxlMLYgiqyeOmT76WuDOrB1lCLS8u4pWcod3viWQ.png' downloaded successfully!
# Image 'nT5jZCrlH_9oFmRB2WmvGKPVUC-heNvUExDsJS8r2dY.png' downloaded successfully!
# Image 'xFtSQGNkmJ1isuzueWZDWVOoLCB1FSZp_O0fHo4o-UA.png' downloaded successfully!
# Image '9TkKFNEBqJ7NYIERZpgPokV3g9dITlyiPXYY4U-oewY.png' downloaded successfully!
# Error downloading image '1.png': unknown url type: '1'
# Image 'NjxPpIkW0XcUHzYR-hwWtlGwf1nWot31N2NMu55slBI.png' downloaded successfully!
# Image 'PoVhF0dFFIgWrmcwV1q09MpNJP6K6i1n4QcnL-hgPbA.png' downloaded successfully!
# Image 'ENxhuqD2QAlepw8Hzi7Ghd4UIfxZ3vYEZdtTCgzSo2k.png' downloaded successfully!
# Image 'Vt9eGdYoRDEznY8E7BwCXaH0IRp5D5YducbhEpuulVQ.png' downloaded successfully!
# Image 'X2C7gOA0UdxrsD-nq-pEdjL1DR4wwSqyu4vCKI4o73o.png' downloaded successfully!
# Image 'bPn3bi8wfhHAn1fJ7W-zW8cDOVpLk9VcDPl9hNCCX4s.png' downloaded successfully!
# Image 'wUORT5YA_dI97z29epaJB7M-JnDZ28zh0VIeU91zU_4.png' downloaded successfully!

# %% [markdown]
# **Firebase Integration**

# %%
import firebase_admin
from firebase_admin import ml
from firebase_admin import credentials

firebase_admin.initialize_app(
  credentials.Certificate('service_account.json'),
  options={
      'storageBucket': 'trial-537bb',
  })

# %%
from firebase_admin import ml
source = ml.TFLiteGCSModelSource.from_tflite_model_file('my_model.tflite')

tflite_format = ml.TFLiteFormat(model_source=source)
model = ml.Model(
    display_name="val_model",
    model_format=tflite_format)

new_model = ml.create_model(model)
ml.publish_model(new_model.model_id)
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:2607, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2606 try:
# -> 2607     created_json = self._do_upload(
#    2608         client,
#    2609         file_obj,
#    2610         content_type,
#    2611         size,
#    2612         num_retries,
#    2613         predefined_acl,
#    2614         if_generation_match,
#    2615         if_generation_not_match,
#    2616         if_metageneration_match,
#    2617         if_metageneration_not_match,
#    2618         timeout=timeout,
#    2619         checksum=checksum,
#    2620         retry=retry,
#    2621         command=command,
#    2622     )
#    2623     self._set_properties(created_json)
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:2430, in Blob._do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2429 else:
# -> 2430     response = self._do_resumable_upload(
#    2431         client,
#    2432         stream,
#    2433         content_type,
#    2434         size,
#    2435         num_retries,
#    2436         predefined_acl,
#    2437         if_generation_match,
#    2438         if_generation_not_match,
#    2439         if_metageneration_match,
#    2440         if_metageneration_not_match,
#    2441         timeout=timeout,
#    2442         checksum=checksum,
#    2443         retry=retry,
#    2444         command=command,
#    2445     )
#    2447 return response.json()
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:2248, in Blob._do_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2151 """Perform a resumable upload.
#    2152
#    2153 Assumes ``chunk_size`` is not :data:`None` on the current blob.
#    (...)
#    2246           is uploaded.
#    2247 """
# -> 2248 upload, transport = self._initiate_resumable_upload(
#    2249     client,
#    2250     stream,
#    2251     content_type,
#    2252     size,
#    2253     num_retries,
#    2254     predefined_acl=predefined_acl,
#    2255     if_generation_match=if_generation_match,
#    2256     if_generation_not_match=if_generation_not_match,
#    2257     if_metageneration_match=if_metageneration_match,
#    2258     if_metageneration_not_match=if_metageneration_not_match,
#    2259     timeout=timeout,
#    2260     checksum=checksum,
#    2261     retry=retry,
#    2262     command=command,
#    2263 )
#    2264 while not upload.finished:
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:2122, in Blob._initiate_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, extra_headers, chunk_size, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2118 upload._retry_strategy = _api_core_retry_to_resumable_media_retry(
#    2119     retry, num_retries
#    2120 )
# -> 2122 upload.initiate(
#    2123     transport,
#    2124     stream,
#    2125     object_metadata,
#    2126     content_type,
#    2127     total_bytes=size,
#    2128     stream_final=False,
#    2129     timeout=timeout,
#    2130 )
#    2132 return upload, transport
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\resumable_media\requests\upload.py:420, in ResumableUpload.initiate(self, transport, stream, metadata, content_type, total_bytes, stream_final, timeout)
#     418     return result
# --> 420 return _request_helpers.wait_and_retry(
#     421     retriable_request, self._get_status_code, self._retry_strategy
#     422 )
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\resumable_media\requests\_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\resumable_media\requests\upload.py:416, in ResumableUpload.initiate.<locals>.retriable_request()
#     412 result = transport.request(
#     413     method, url, data=payload, headers=headers, timeout=timeout
#     414 )
# --> 416 self._process_initiate_response(result)
#     418 return result
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\resumable_media\_upload.py:518, in ResumableUpload._process_initiate_response(self, response)
#     503 """Process the response from an HTTP request that initiated upload.
#     504
#     505 This is everything that must be done after a request that doesn't
#    (...)
#     516 .. _sans-I/O: https://sans-io.readthedocs.io/
#     517 """
# --> 518 _helpers.require_status_code(
#     519     response,
#     520     (http.client.OK, http.client.CREATED),
#     521     self._get_status_code,
#     522     callback=self._make_invalid,
#     523 )
#     524 self._resumable_url = _helpers.header_required(
#     525     response, "location", self._get_headers
#     526 )
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\resumable_media\_helpers.py:108, in require_status_code(response, status_codes, get_status_code, callback)
#     107         callback()
# --> 108     raise common.InvalidResponse(
#     109         response,
#     110         "Request failed with status code",
#     111         status_code,
#     112         "Expected one of",
#     113         *status_codes
#     114     )
#     115 return status_code
#
# InvalidResponse: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.CREATED: 201>)
#
# During handling of the above exception, another exception occurred:
#
# NotFound                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 from firebase_admin import ml
# ----> 2 source = ml.TFLiteGCSModelSource.from_tflite_model_file('my_model.tflite')
#       4 tflite_format = ml.TFLiteFormat(model_source=source)
#       5 model = ml.Model(
#       6     display_name="val_model",  # This is the name you use from your app to load the model.
#       7     model_format=tflite_format)
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\firebase_admin\ml.py:510, in TFLiteGCSModelSource.from_tflite_model_file(cls, model_file_name, bucket_name, app)
#     494 @classmethod
#     495 def from_tflite_model_file(cls, model_file_name, bucket_name=None, app=None):
#     496     """Uploads the model file to an existing Google Cloud Storage bucket.
#     497
#     498     Args:
#    (...)
#     508         ImportError: If the Cloud Storage Library has not been installed.
#     509     """
# --> 510     gcs_uri = TFLiteGCSModelSource._STORAGE_CLIENT.upload(bucket_name, model_file_name, app)
#     511     return TFLiteGCSModelSource(gcs_tflite_uri=gcs_uri, app=app)
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\firebase_admin\ml.py:460, in _CloudStorageClient.upload(bucket_name, model_file_name, app)
#     458 blob_name = _CloudStorageClient.BLOB_NAME.format(file_name)
#     459 blob = bucket.blob(blob_name)
# --> 460 blob.upload_from_filename(model_file_name)
#     461 return _CloudStorageClient.GCS_URI.format(bucket.name, blob_name)
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:2929, in Blob.upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2807 def upload_from_filename(
#    2808     self,
#    2809     filename,
#    (...)
#    2820     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2821 ):
#    2822     """Upload this blob's contents from the content of a named file.
#    2823
#    2824     The content type of the upload will be determined in order
#    (...)
#    2926         are respected.
#    2927     """
# -> 2929     self._handle_filename_and_upload(
#    2930         filename,
#    2931         content_type=content_type,
#    2932         num_retries=num_retries,
#    2933         client=client,
#    2934         predefined_acl=predefined_acl,
#    2935         if_generation_match=if_generation_match,
#    2936         if_generation_not_match=if_generation_not_match,
#    2937         if_metageneration_match=if_metageneration_match,
#    2938         if_metageneration_not_match=if_metageneration_not_match,
#    2939         timeout=timeout,
#    2940         checksum=checksum,
#    2941         retry=retry,
#    2942     )
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:2799, in Blob._handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2797 with open(filename, "rb") as file_obj:
#    2798     total_bytes = os.fstat(file_obj.fileno()).st_size
# -> 2799     self._prep_and_do_upload(
#    2800         file_obj,
#    2801         content_type=content_type,
#    2802         size=total_bytes,
#    2803         *args,
#    2804         **kwargs,
#    2805     )
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:2625, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2623     self._set_properties(created_json)
#    2624 except resumable_media.InvalidResponse as exc:
# -> 2625     _raise_from_invalid_response(exc)
#
# File c:\Users\aswin\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\cloud\storage\blob.py:4791, in _raise_from_invalid_response(error)
#    4787     error_message = str(error)
#    4789 message = f"{response.request.method} {response.request.url}: {error_message}"
# -> 4791 raise exceptions.from_http_status(response.status_code, message, response=response)
#
# NotFound: 404 POST https://storage.googleapis.com/upload/storage/v1/b/trial-537bb/o?uploadType=resumable: {
#   "error": {
#     "code": 404,
#     "message": "The specified bucket does not exist.",
#     "errors": [
#       {
#         "message": "The specified bucket does not exist.",
#         "domain": "global",
#         "reason": "notFound"
#       }
#     ]
#   }
# }
# : ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.CREATED: 201>)
